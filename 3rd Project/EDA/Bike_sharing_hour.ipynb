# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from dateutil.parser import parse 
import matplotlib as mpl

# %%
df = pd.read_csv("/Users/ms/Desktop/Boot Camp /3rd Project/Bike-Sharing-Dataset/hour.csv" )

# %%
df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.shape
# Out:
# (17379, 17)

# %%
df['temp'].nlargest(5)
# Out:
# 13163    1.00
# 12972    0.98
# 4768     0.96
# 4934     0.96
# 4936     0.96
# Name: temp, dtype: float64

# %%
# convert the Temprutre to Celsius , humidity and windspeed  

t_min= -8
t_max=39
t_min_a=16
t_max_a= -50

df['temp'] = df['temp'] * (t_max-t_min) + t_min 
df['atemp'] = df['atemp'] *  (t_max_a-t_min_a) + t_min_a
df['real_hum']= df['hum']*100
df['real_windspeed']= df['windspeed']*67

# %%
df['temp'].nlargest(5)
# Out:
# 13163    39.00
# 12972    38.06
# 4768     37.12
# 4934     37.12
# 4936     37.12
# Name: temp, dtype: float64

# %%
df['temp'].nsmallest(5)
# Out:
# 483   -7.06
# 484   -7.06
# 485   -7.06
# 486   -7.06
# 504   -7.06
# Name: temp, dtype: float64

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283     15.358397
# ...

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  3.28 -3.0014  0.81        0.0       3          13   16
# 1           1  2.34 -1.9982  0.80        0.0       8          32   40
# 2           1  2.34 -1.9982  0.80        0.0       5          27   32
# 3           1  3.28 -3.0014  0.75        0.0       3          10   13
# 4           1  3.28 -3.0014  0.75        0.0       0           1    1
#
#    real_hum  real_windspeed
# 0      81.0             0.0
# 1      80.0             0.0
# ...

# %%
df.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  4.22 -1.0016  0.60     0.1642      11
# 17375           1           2  4.22 -1.0016  0.60     0.1642       8
# 17376           1           1  4.22 -1.0016  0.60     0.1642       7
# 17377           1           1  4.22 -1.9982  0.56     0.1343      13
# 17378           1           1  4.22 -1.9982  0.65     0.1343      12
#
#        registered  cnt  real_hum  real_windspeed
# 17374         108  119      60.0         11.0014
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   instant         17379 non-null  int64
#  1   dteday          17379 non-null  object
#  2   season          17379 non-null  int64
#  3   yr              17379 non-null  int64
#  4   mnth            17379 non-null  int64
#  5   hr              17379 non-null  int64
#  6   holiday         17379 non-null  int64
#  7   weekday         17379 non-null  int64
#  8   workingday      17379 non-null  int64
#  9   weathersit      17379 non-null  int64
#  10  temp            17379 non-null  float64
#  11  atemp           17379 non-null  float64
#  12  hum             17379 non-null  float64
#  13  windspeed       17379 non-null  float64
#  14  casual          17379 non-null  int64
#  15  registered      17379 non-null  int64
#  16  cnt             17379 non-null  int64
# ...

# %%
df.notna()
# Out:
#        instant  dteday  season    yr  mnth    hr  holiday  weekday  \
# 0         True    True    True  True  True  True     True     True
# 1         True    True    True  True  True  True     True     True
# 2         True    True    True  True  True  True     True     True
# 3         True    True    True  True  True  True     True     True
# 4         True    True    True  True  True  True     True     True
# ...        ...     ...     ...   ...   ...   ...      ...      ...
# 17374     True    True    True  True  True  True     True     True
# 17375     True    True    True  True  True  True     True     True
# 17376     True    True    True  True  True  True     True     True
# 17377     True    True    True  True  True  True     True     True
# 17378     True    True    True  True  True  True     True     True
#
#        workingday  weathersit  temp  atemp   hum  windspeed  casual  \
# 0            True        True  True   True  True       True    True
# ...

# %%
# change column names to sound appropriate

df.rename(columns= {'yr' : 'year' , 'mnth' : 'month', 'hr' : 'hour', 'hum' : 'humidity', 'dteday' : 'date' , 'cnt' : 'count'} , inplace= True)

# %%
# conversion date type from object to timestamp.

df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# instant                    int64
# date              datetime64[ns]
# season                     int64
# year                       int64
# month                      int64
# hour                       int64
# holiday                    int64
# weekday                    int64
# workingday                 int64
# weathersit                 int64
# temp                     float64
# atemp                    float64
# humidity                 float64
# windspeed                float64
# casual                     int64
# registered                 int64
# cnt                        int64
# real_hum                 float64
# real_windspeed           float64
# dtype: object

# %%
# conversion integres attributes to categoricals for proper understanding

df.loc[df['holiday'] == 0, 'holiday'] = 'No'
df.loc[df['holiday'] == 1, 'holiday'] = 'Yes'
df.loc[df['workingday'] == 0, 'workingday'] = 'No'
df.loc[df['workingday'] == 1, 'workingday'] = 'Yes'
df.loc[df['season'] == 1, 'season'] = 'Winter'
df.loc[df['season'] == 2, 'season'] = 'Spring'
df.loc[df['season'] == 3, 'season'] = 'Summer'
df.loc[df['season'] == 4, 'season'] = 'Fall'
df.loc[df['weekday'] == 0, 'weekday'] = 'Sunday'
df.loc[df['weekday'] == 1, 'weekday'] = 'Monday'
df.loc[df['weekday'] == 2, 'weekday'] = 'Tuesday'
df.loc[df['weekday'] == 3, 'weekday'] = 'Wednsday'
df.loc[df['weekday'] == 4, 'weekday'] = 'Thursday'
df.loc[df['weekday'] == 5, 'weekday'] = 'Friday'
df.loc[df['weekday'] == 6, 'weekday'] = 'Saturday'
df.loc[df['year'] == 0, 'year'] = '2011'
df.loc[df['year'] == 1, 'year'] = '2012'

# %%
df.head(10)
# Out:
#    instant       date  season  year  month  hour holiday   weekday workingday  \
# 0        1 2011-01-01  Winter  2011      1     0      No  Saturday         No
# 1        2 2011-01-01  Winter  2011      1     1      No  Saturday         No
# 2        3 2011-01-01  Winter  2011      1     2      No  Saturday         No
# 3        4 2011-01-01  Winter  2011      1     3      No  Saturday         No
# 4        5 2011-01-01  Winter  2011      1     4      No  Saturday         No
# 5        6 2011-01-01  Winter  2011      1     5      No  Saturday         No
# 6        7 2011-01-01  Winter  2011      1     6      No  Saturday         No
# 7        8 2011-01-01  Winter  2011      1     7      No  Saturday         No
# 8        9 2011-01-01  Winter  2011      1     8      No  Saturday         No
# 9       10 2011-01-01  Winter  2011      1     9      No  Saturday         No
#
#    weathersit  temp   atemp  humidity  windspeed  casual  registered  count  \
# ...

# %%
df.value_counts('weathersit')
# Out:
# weathersit
# 1    11413
# 2     4544
# 3     1419
# 4        3
# dtype: int64

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
#fmri = sns.load_dataset("df")

# Plot the responses for different events and regions
sns.lineplot(x="hour", y="count",
             hue="season", 
             data=df)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %%
# Season wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

lplt = sns.lineplot( data=df, x="hour", y="count",  err_style="bars", hue="season" )
lplt.set_xticks(range(24))
lplt.grid(False)
lplt.set_title('Season wise hourly distribution of bike rentals')
# Out:
# Text(0.5, 1.0, 'Season wise hourly distribution of bike rentals')

# %%
# Holiday wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

lplt = sns.lineplot( data=df, x="hour", y="count", hue="holiday", markers=True, dashes=False )
lplt.set_xticks(range(24))
#lplt.grid(False)
lplt.set_title('Holiday wise hourly distribution of bike rentals')
# Out:
# Text(0.5, 1.0, 'Holiday wise hourly distribution of bike rentals')

# %%
# Weather situation wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

lplt = sns.lineplot( data=df, x="hour", y="count",  err_style="bars", hue="weathersit" )
lplt.set_xticks(range(24))
lplt.grid(False)
lplt.set_title('Weather situation wise hourly distribution of bike rentals')
# Out:
# Text(0.5, 1.0, 'Weather situation wise hourly distribution of bike rentals')

# %%
# year wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

lplt = sns.lineplot( data=df, x="hour", y="count", hue="year", markers=True, dashes=False )
lplt.set_xticks(range(24))
lplt.grid(False)
lplt.set_title('Year wise hourly distribution of bike rentals')
# Out:
# Text(0.5, 1.0, 'Year wise hourly distribution of bike rentals')

# %%
# year wise monthly distribution of bike rentals

plt.figure(figsize=(12,8))

lplt = sns.lineplot( data=df, x="month", y="count", hue="year", markers=True, dashes=False )
lplt.set_xticks(range(1, 13))


#lplt.grid(False)
lplt.set_title('Year wise monthly distribution of bike rentals')
lplt.set_ylabel("mean count of rental bike")
lplt.set_xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
# 2011 and 2012 wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

barplt = sns.barplot( data=df, x= "month", y="count")
 
barplt.grid(False)
barplt.set_title('2011 and 2012 Year wise monthly distribution of bike rentals')
barplt.set_ylabel("mean count of rental bike")
barplt.set_xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.figure(figsize=(12,8))

barplt = sns.barplot( data=df, x= df["month"][df['year'] == '2011'], y="count")
 
barplt.grid(False)
barplt.set_title('2011 Year wise monthly distribution of bike rentals')
barplt.set_ylabel("mean count of rental bike")
barplt.set_xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.figure(figsize=(12,8))

barplt = sns.barplot( data=df, x= df["month"][df['year'] == '2012'], y="count")
 
barplt.grid(False)
barplt.set_title('2012 Year wise monthly distribution of bike rentals')
barplt.set_ylabel("mean count of rental bike")
barplt.set_xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
# winter wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

lplt = sns.lineplot( data=df, x=df["hour"][df['season'] == 'Winter'], y="count", hue="weathersit", markers=True, dashes=False )
lplt.set_xticks(range(24))
lplt.grid(False)
lplt.set_title('winter wise hourly distribution of bike rentals')
# Out:
# Text(0.5, 1.0, 'winter wise hourly distribution of bike rentals')

# %%
# Weather situation wise distribution of bike rentals

plt.figure(figsize=(12,8))

barplt = sns.barplot( data=df, x= "weathersit", y="count")
 
barplt.grid(False)
barplt.set_title('Weather situation wise distribution of bike rentals')
barplt.set_ylabel("mean count of rental bike")
barplt.set_xlabel('Weather Situation')
# Out:
# Text(0.5, 0, 'Weather Situation')

# %%
df.rename(columns= {'weekday' : 'day'} , inplace= True)

# %%
# creat a is_weekend column 

df['is_weekend'] = df['day'].apply(lambda x: 'Yes' if x == 'Saturday' else 'Yes' if x == 'Sunday'
 else 'No')

df['is_weekend'] = pd.Categorical(df['is_weekend'],categories=['Yes', 'No'])

# %%
# Weekend wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

lplt = sns.lineplot( data=df, x="hour", y="count",  markers=True, dashes=False, hue="is_weekend" )
lplt.set_xticks(range(24))
lplt.grid(False)
lplt.set_title('Weekend situation wise hourly distribution of bike rentals')
# Out:
# Text(0.5, 1.0, 'Weekend situation wise hourly distribution of bike rentals')

# %%
# Holiday wise hourly distribution of bike rentals

plt.figure(figsize=(12,8))

hue_order = ['Yes', 'No']

lplt = sns.lineplot( data=df, x="hour", y="count", hue="holiday", markers=True, dashes=False, hue_order= hue_order)
lplt.set_xticks(range(24))
lplt.grid(False)
lplt.set_title('Holiday wise hourly distribution of bike rentals')
# Out:
# Text(0.5, 1.0, 'Holiday wise hourly distribution of bike rentals')

# %%
df.head()
# Out:
#    instant       date  season  year  month  hour holiday       day workingday  \
# 0        1 2011-01-01  Winter  2011      1     0      No  Saturday         No
# 1        2 2011-01-01  Winter  2011      1     1      No  Saturday         No
# 2        3 2011-01-01  Winter  2011      1     2      No  Saturday         No
# 3        4 2011-01-01  Winter  2011      1     3      No  Saturday         No
# 4        5 2011-01-01  Winter  2011      1     4      No  Saturday         No
#
#    weathersit  temp   atemp  humidity  windspeed  casual  registered  count  \
# 0           1  3.28 -3.0014      0.81        0.0       3          13     16
# 1           1  2.34 -1.9982      0.80        0.0       8          32     40
# 2           1  2.34 -1.9982      0.80        0.0       5          27     32
# 3           1  3.28 -3.0014      0.75        0.0       3          10     13
# 4           1  3.28 -3.0014      0.75        0.0       0           1      1
#
#    real_hum  real_windspeed is_weekend
# ...

# %% [markdown]
# Time Series

# %%
parse_dates=['date']

# %%
df.head()
# Out:
#    instant       date  season  year  month  hour holiday       day workingday  \
# 0        1 2011-01-01  Winter  2011      1     0      No  Saturday         No
# 1        2 2011-01-01  Winter  2011      1     1      No  Saturday         No
# 2        3 2011-01-01  Winter  2011      1     2      No  Saturday         No
# 3        4 2011-01-01  Winter  2011      1     3      No  Saturday         No
# 4        5 2011-01-01  Winter  2011      1     4      No  Saturday         No
#
#    weathersit  temp   atemp  humidity  windspeed  casual  registered  count  \
# 0           1  3.28 -3.0014      0.81        0.0       3          13     16
# 1           1  2.34 -1.9982      0.80        0.0       8          32     40
# 2           1  2.34 -1.9982      0.80        0.0       5          27     32
# 3           1  3.28 -3.0014      0.75        0.0       3          10     13
# 4           1  3.28 -3.0014      0.75        0.0       0           1      1
#
#    real_hum  real_windspeed is_weekend
# ...
